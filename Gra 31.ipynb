# %%
# Biblioteki
from random import sample
from random import randint

import matplotlib.pyplot as plt

# %%
# Rodzaje kart
wartosci = range(2,15)
figury = ["kier", "pik", "karo", "trefl"]

# Talia
talia = [(wartosc, figura) for figura in figury for wartosc in wartosci]

# Sprawdzenie
# len(talia) # 52 elementy
# talia # wydrukuj

# %%
# Słownik punktów
punkty = {}

for karta in talia:
    if karta[0] <= 10:
        punkty[karta] = karta[0]
    else:
        punkty[karta] = 10

# Sprawdzenie
# punkty

# %%
# Ustawienia gry - ręczne
liczba_graczy = 3
liczba_kart = 3
minimalne_punkty = 24

# %%
# Ustawienia gry - automatyczne

licznik = []
wylosowane_karty = []
# Wygeneruj graczy jako słowniki
gracze = range(liczba_graczy)

# Sprawdź
# karty_w_rece
# liczba_punktow

# %%
# Wylosuj kartę - funkcja
def losuj_karte(uzyte_karty = wylosowane_karty):
    jest_w_wylosowanych = True
    
    while jest_w_wylosowanych == True:
        id_karty = randint(0, len(talia)-1)
        karta = talia[id_karty]
        jest_w_wylosowanych = id_karty in list(uzyte_karty)
    return(karta, id_karty)

# Sprawdź
# losuj_karte()

# %%
# Rozpoczęcie gry
karty_w_rece = {}
historia_kart = {}

# Stosik
wybrana_karta = losuj_karte()
stosik = wybrana_karta[0]
wylosowane_karty.append(wybrana_karta[1])
print('Na stosiku jest ', stosik)

# Gracze losują pierwsze karty
for gracz in gracze:
    # Wylosuj po liczba_kart kart
    karty_gracza = []
    for los in range(liczba_kart):
        wybrana_karta = losuj_karte()
        karty_gracza.append(wybrana_karta[0])
        wylosowane_karty.append(wybrana_karta[1])
    karty_w_rece[gracz] = karty_gracza
    historia_kart[gracz] = [karty_gracza]
    print("Gracz", gracz, "wylosował karty",karty_w_rece[gracz])
# Out:
# Na stosiku jest  (12, 'kier')
# Gracz 0 wylosował karty [(9, 'trefl'), (14, 'karo'), (4, 'pik')]
# Gracz 1 wylosował karty [(7, 'kier'), (10, 'pik'), (6, 'kier')]

# %%
historia_kart
# Out:
# {0: [[(9, 'trefl'), (14, 'karo'), (4, 'pik')]], 1: [[(7, 'kier'), (10, 'pik'), (6, 'kier')]]}

# %%
def policz_punkty(karty, slownik_punktow = punkty):
    pkt = {}
    
    for karta in karty:
        aktualne_w_kolorze = pkt.get(karta[1], 0)
        aktualne_w_kolorze += slownik_punktow[karta]
        pkt[karta[1]] = aktualne_w_kolorze
    return(pkt)

def wybierz_strategie(pkt):
    inverse = [(value, key) for key, value in pkt.items()]
    return(max(inverse)[1])

# Sprawdź
# policz_punkty([(8, 'kier'), (3, 'trefl'), (14, 'karo')])
# policz_punkty([(2, 'trefl'), (2, 'kier'), (5, 'kier')])
# wybierz_strategie(policz_punkty([(2, 'trefl'), (2, 'kier'), (5, 'kier')]))
# wybierz_strategie(policz_punkty([(8, 'kier'), (3, 'trefl'), (14, 'karo')]))
# wybierz_strategie(policz_punkty([(8, 'kier'), (10, 'trefl'), (14, 'karo')]))

# %%
def dopnij_nowa_karte_do_kart_gracza(lista_kart_w_rece, nowa_karta):
    nowe_karty = lista_kart_w_rece.copy()
    nowe_karty.append(nowa_karta)
    return(nowe_karty)

# %%
kontynuuj_gre = True
do_konca_zostalo_n_ruchow = liczba_graczy - 1
licznik_rund = 0

while do_konca_zostalo_n_ruchow > 0:
    licznik_rund += 1
    print("Runda", licznik_rund)
    for gracz in gracze:
        print(3*'-', "Gracz", gracz, 3*"-")
        strategia_ind = False 
        
        # Strategia 1: weź stosik, jeśli zgadza się kolor
        print("Analiza wzięcia karty ze stosika")
        nowe_karty = karty_w_rece[gracz].copy()
        nowe_karty.append(stosik)
        print("Karty do rozważenia to", nowe_karty)
        punkty_gracza = policz_punkty(nowe_karty)
        strategia = wybierz_strategie(punkty_gracza)
        print("Strategia dominująca to", strategia)
        
        if stosik[1] == strategia:
            print("Karta ze stosika jest zgodna z kolorem strategicznym")
            nowe_karty.sort()
            if len(punkty_gracza) == 1: # jeśli wszystkie 1 koloru, wyrzuć najmniejszą
                print("Wszystkie karty są tego samego koloru")
                karta_do_wyrzucenia_na_stosik = nowe_karty[0]
                print("Zostanie wyrzucona", karta_do_wyrzucenia_na_stosik)
                
                strategia_ind = True
                stosik = karta_do_wyrzucenia_na_stosik
                karty_w_rece[gracz] = nowe_karty[1:]
                historia_kart[gracz].append(karty_w_rece[gracz])
                print("Nowe karty gracza to", karty_w_rece[gracz])
            else: # jeśli nie wszystkie 1 koloru, wyrzuć najmniejszą koloru niestrategicznego
                print("Nie wszystkie karty są tego samego koloru")
                do_usuwania = [(wartosc, kolor) for wartosc,kolor in nowe_karty if kolor != strategia]
                print("Usuń którąś z", do_usuwania)
                
                strategia_ind = True
                stosik = do_usuwania[0]
                nowe_karty.remove(stosik)
                karty_w_rece[gracz] = nowe_karty
                historia_kart[gracz].append(karty_w_rece[gracz])                
                print("Nowe karty gracza to", karty_w_rece[gracz])
            
        # Strategia 2: wylosuj nową kartę
        if strategia_ind == False:
            print("Gracz bierze z kupki kart")
            wylosowana_karta = losuj_karte()
            wylosowane_karty.append(wylosowana_karta[1])
            print("Gracz wylosował", wylosowana_karta[0])
            
            nowe_karty = karty_w_rece[gracz].copy()
            nowe_karty.append(wylosowana_karta[0])        
            punkty_gracza = policz_punkty(nowe_karty)
            strategia = wybierz_strategie(punkty_gracza)
            
            if wylosowana_karta[0][1] == strategia: # jeśli pasuje do strategii
                print("Karta wylosowana jest zgodna z kolorem strategicznym")
                nowe_karty.sort()
                
                if len(punkty_gracza) == 1: # jeśli wszystkie 1 koloru, wyrzuć najmniejszą
                    print("Wszystkie karty są tego samego koloru")
                    karta_do_wyrzucenia_na_stosik = nowe_karty[0]
                    print("Zostanie wyrzucona", karta_do_wyrzucenia_na_stosik)

                    strategia_ind = True
                    stosik = karta_do_wyrzucenia_na_stosik
                    karty_w_rece[gracz] = nowe_karty[1:]
                    historia_kart[gracz].append(karty_w_rece[gracz])
                    print("Nowe karty gracza to", karty_w_rece[gracz])
                else: # jeśli nie wszystkie 1 koloru, wyrzuć najmniejszą koloru niestrategicznego
                    print("Nie wszystkie karty są tego samego koloru")
                    do_usuwania = [(wartosc, kolor) for wartosc,kolor in nowe_karty if kolor != strategia]
                    print("Usuń którąś z", do_usuwania)

                    strategia_ind = True
                    stosik = do_usuwania[0]
                    nowe_karty.remove(stosik)
                    karty_w_rece[gracz] = nowe_karty
                    historia_kart[gracz].append(karty_w_rece[gracz])
                    print("Nowe karty gracza to", karty_w_rece[gracz])
            
            else: # Jeśli nie strategia 2, wyrzuć kartę na stosik
                print("Karta wylosowana nie jest zgodna z kolorem strategicznym - idzie na stosik")
                stosik = wylosowana_karta[0]
                historia_kart[gracz].append(karty_w_rece[gracz])
        
        # Odlicz ruch, jeśli jesteśmy w końcowej fazie
        if kontynuuj_gre == False:
            do_konca_zostalo_n_ruchow -= 1
            print("Do końca gry pozostało", do_konca_zostalo_n_ruchow, "graczy")
            
        # Sprawdź, czy kończymy grę
        if kontynuuj_gre == True:
            punkty_gracza = policz_punkty(karty_w_rece[gracz])
            inverse = [(value, key) for key, value in punkty_gracza.items()]
            if max(inverse)[0] > minimalne_punkty:
                kontynuuj_gre = False
                print("Gracz", gracz, "ma", max(inverse)[0], "punktów. Koniec gry za chwilę.")

licznik.append(licznik_rund)
# Out:
# Runda 1
# --- Gracz 0 ---
# Analiza wzięcia karty ze stosika
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [9]:
# Line 14:    nowe_karty = karty_w_rece[gracz].copy()
#
# NameError: name 'karty_w_rece' is not defined
# ---------------------------------------------------------------------------

# %%
licznik
# Out:
# [3, 5]

# %%
iteracje = 1000

for i in range(iteracje):
    print("Iteracja", i)
    # Rozpoczęcie gry
    karty_w_rece = {}
    historia_kart = {}
    wylosowane_karty = []

    # Stosik
    wybrana_karta = losuj_karte()
    stosik = wybrana_karta[0]
    wylosowane_karty.append(wybrana_karta[1])
#     print('Na stosiku jest ', stosik)

    # Gracze losują pierwsze karty
    for gracz in gracze:
        # Wylosuj po liczba_kart kart
        karty_gracza = []
        for los in range(liczba_kart):
            wybrana_karta = losuj_karte()
            karty_gracza.append(wybrana_karta[0])
            wylosowane_karty.append(wybrana_karta[1])
        karty_w_rece[gracz] = karty_gracza
        historia_kart[gracz] = [karty_gracza]
#         print("Gracz", gracz, "wylosował karty",karty_w_rece[gracz])

    ###########################

    kontynuuj_gre = True
    do_konca_zostalo_n_ruchow = liczba_graczy - 1
    licznik_rund = 0

    while do_konca_zostalo_n_ruchow > 0:
        licznik_rund += 1
#         print("Runda", licznik_rund)
        for gracz in gracze:
#             print(3*'-', "Gracz", gracz, 3*"-")
            strategia_ind = False 

            # Strategia 1: weź stosik, jeśli zgadza się kolor
#             print("Analiza wzięcia karty ze stosika")
            nowe_karty = karty_w_rece[gracz].copy()
            nowe_karty.append(stosik)
#             print("Karty do rozważenia to", nowe_karty)
            punkty_gracza = policz_punkty(nowe_karty)
            strategia = wybierz_strategie(punkty_gracza)
#             print("Strategia dominująca to", strategia)

            if stosik[1] == strategia:
#                 print("Karta ze stosika jest zgodna z kolorem strategicznym")
                nowe_karty.sort()
                if len(punkty_gracza) == 1: # jeśli wszystkie 1 koloru, wyrzuć najmniejszą
#                     print("Wszystkie karty są tego samego koloru")
                    karta_do_wyrzucenia_na_stosik = nowe_karty[0]
#                     print("Zostanie wyrzucona", karta_do_wyrzucenia_na_stosik)

                    strategia_ind = True
                    stosik = karta_do_wyrzucenia_na_stosik
                    karty_w_rece[gracz] = nowe_karty[1:]
                    historia_kart[gracz].append(karty_w_rece[gracz])
#                     print("Nowe karty gracza to", karty_w_rece[gracz])
                else: # jeśli nie wszystkie 1 koloru, wyrzuć najmniejszą koloru niestrategicznego
#                     print("Nie wszystkie karty są tego samego koloru")
                    do_usuwania = [(wartosc, kolor) for wartosc,kolor in nowe_karty if kolor != strategia]
#                     print("Usuń którąś z", do_usuwania)

                    strategia_ind = True
                    stosik = do_usuwania[0]
                    nowe_karty.remove(stosik)
                    karty_w_rece[gracz] = nowe_karty
                    historia_kart[gracz].append(karty_w_rece[gracz])                
#                     print("Nowe karty gracza to", karty_w_rece[gracz])

            # Strategia 2: wylosuj nową kartę
            if strategia_ind == False:
#                 print("Gracz bierze z kupki kart")
                wylosowana_karta = losuj_karte()
                wylosowane_karty.append(wylosowana_karta[1])
#                 print("Gracz wylosował", wylosowana_karta[0])

                nowe_karty = karty_w_rece[gracz].copy()
                nowe_karty.append(wylosowana_karta[0])        
                punkty_gracza = policz_punkty(nowe_karty)
                strategia = wybierz_strategie(punkty_gracza)

                if wylosowana_karta[0][1] == strategia: # jeśli pasuje do strategii
#                     print("Karta wylosowana jest zgodna z kolorem strategicznym")
                    nowe_karty.sort()

                    if len(punkty_gracza) == 1: # jeśli wszystkie 1 koloru, wyrzuć najmniejszą
#                         print("Wszystkie karty są tego samego koloru")
                        karta_do_wyrzucenia_na_stosik = nowe_karty[0]
#                         print("Zostanie wyrzucona", karta_do_wyrzucenia_na_stosik)

                        strategia_ind = True
                        stosik = karta_do_wyrzucenia_na_stosik
                        karty_w_rece[gracz] = nowe_karty[1:]
                        historia_kart[gracz].append(karty_w_rece[gracz])
#                         print("Nowe karty gracza to", karty_w_rece[gracz])
                    else: # jeśli nie wszystkie 1 koloru, wyrzuć najmniejszą koloru niestrategicznego
#                         print("Nie wszystkie karty są tego samego koloru")
                        do_usuwania = [(wartosc, kolor) for wartosc,kolor in nowe_karty if kolor != strategia]
#                         print("Usuń którąś z", do_usuwania)

                        strategia_ind = True
                        stosik = do_usuwania[0]
                        nowe_karty.remove(stosik)
                        karty_w_rece[gracz] = nowe_karty
                        historia_kart[gracz].append(karty_w_rece[gracz])
#                         print("Nowe karty gracza to", karty_w_rece[gracz])

                else: # Jeśli nie strategia 2, wyrzuć kartę na stosik
#                     print("Karta wylosowana nie jest zgodna z kolorem strategicznym - idzie na stosik")
                    stosik = wylosowana_karta[0]
                    historia_kart[gracz].append(karty_w_rece[gracz])

            # Odlicz ruch, jeśli jesteśmy w końcowej fazie
            if kontynuuj_gre == False:
                do_konca_zostalo_n_ruchow -= 1
#                 print("Do końca gry pozostało", do_konca_zostalo_n_ruchow, "graczy")

            # Sprawdź, czy kończymy grę
            if kontynuuj_gre == True:
                punkty_gracza = policz_punkty(karty_w_rece[gracz])
                inverse = [(value, key) for key, value in punkty_gracza.items()]
                if max(inverse)[0] > minimalne_punkty:
                    kontynuuj_gre = False
#                     print("Gracz", gracz, "ma", max(inverse)[0], "punktów. Koniec gry za chwilę.")

            # Sprawdź, czy trzeba zmienić talię
            if len(wylosowane_karty) > 45:
                wylosowane_karty = []
                stos_ind = talia.index(stosik)
                wylosowane_karty.append(stos_ind)
                for gracz, karty in karty.items():
                    for karta in karty:
                        karta_ind = talia.index(karta)
                        wylosowane_karty.append(karta_ind)

    licznik.append(licznik_rund)
# Out:
# Iteracja 0
# Iteracja 1
# Iteracja 2
# Iteracja 3
# Iteracja 4
# Iteracja 5
# Iteracja 6
# Iteracja 7
# Iteracja 8
# Iteracja 9
# Iteracja 10
# Iteracja 11
# Iteracja 12
# Iteracja 13
# Iteracja 14
# Iteracja 15
# Iteracja 16
# Iteracja 17
# Iteracja 18
# Iteracja 19
# Iteracja 20
# Iteracja 21
# Iteracja 22
# Iteracja 23
# Iteracja 24
# Iteracja 25
# Iteracja 26
# Iteracja 27
# Iteracja 28
# Iteracja 29
# Iteracja 30
# Iteracja 31
# Iteracja 32
# Iteracja 33
# Iteracja 34
# Iteracja 35
# Iteracja 36
# Iteracja 37
# Iteracja 38
# Iteracja 39
# Iteracja 40
# Iteracja 41
# Iteracja 42
# Iteracja 43
# Iteracja 44
# Iteracja 45
# Iteracja 46
# Iteracja 47
# Iteracja 48
# Iteracja 49
# Iteracja 50
# Iteracja 51
# Iteracja 52
# Iteracja 53
# Iteracja 54
# Iteracja 55
# Iteracja 56
# Iteracja 57
# Iteracja 58
# Iteracja 59
# Iteracja 60
# Iteracja 61
# Iteracja 62
# Iteracja 63
# Iteracja 64
# Iteracja 65
# Iteracja 66
# Iteracja 67
# Iteracja 68
# Iteracja 69
# Iteracja 70
# Iteracja 71
# Iteracja 72
# Iteracja 73
# Iteracja 74
# Iteracja 75
# Iteracja 76
# Iteracja 77
# Iteracja 78
# Iteracja 79
# Iteracja 80
# Iteracja 81
# Iteracja 82
# Iteracja 83
# Iteracja 84
# Iteracja 85
# Iteracja 86
# Iteracja 87
# Iteracja 88
# Iteracja 89
# Iteracja 90
# Iteracja 91
# Iteracja 92
# Iteracja 93
# Iteracja 94
# Iteracja 95
# Iteracja 96
# Iteracja 97
# Iteracja 98
# Iteracja 99
# Iteracja 100
# Iteracja 101
# Iteracja 102
# Iteracja 103
# Iteracja 104
# Iteracja 105
# Iteracja 106
# Iteracja 107
# Iteracja 108
# Iteracja 109
# Iteracja 110
# Iteracja 111
# Iteracja 112
# Iteracja 113
# Iteracja 114
